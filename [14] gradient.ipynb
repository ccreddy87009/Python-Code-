# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# say we have a "loss function" which is denoted as below
func = lambda x: x**2 - 5*x + 10

# %%
# We are passing one variable
func(1)
# Out:
# 6

# %%
# We are passing one variable
func(-1)
# Out:
# 16

# %%
# first differential of our loss function
func_diff = lambda x: 2*x - 5

# %%
func_diff(1)
# Out:
# -3

# %%
# Finding 'x'
x = np.linspace(-10, 10, 400)
x[:5]
# Out:
# array([-10.        ,  -9.94987469,  -9.89974937,  -9.84962406,
#         -9.79949875])

# %%
# finding 'y'
y = func(x)

# %%
y[:5]
# Out:
# array([160.        , 158.74937971, 157.50378452, 156.26321443,
#        155.02766942])

# %%
# gradient 
lr = 0.1   # lr=learning rate
x_start = 9
steps = [x_start]
n_iterations = 50 # how many times i want to update

# %%
for _ in range(n_iterations):
    x_start = x_start - lr * func_diff(x_start)
    steps.append(x_start)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, y, lw=2)

plt.scatter(steps, func(np.array(steps)), c='red', s=100, label='steps')
plt.plot(steps, func(np.array(steps)), color='red', linestyle='--', lw=1.5)
plt.title('Gradient Descent')
plt.xlabel('X')
plt.ylabel('func(X)')
plt.legend()
plt.grid(True)
plt.show()
